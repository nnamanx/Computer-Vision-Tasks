# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('inchi2.png', cv2.IMREAD_GRAYSCALE)

if img is None:
    print("Image not found.")
else:
    median_cleaned = cv2.medianBlur(img, 3)

    mean_blurred = cv2.blur(img, (3, 3))


    _, binary = cv2.threshold(median_cleaned, 170, 255, cv2.THRESH_BINARY)

    kernel = np.ones((2,2), np.uint8)

    final_result = cv2.erode(binary, kernel, iterations=1)

    titles = ['Original Noisy Image', 'Mean Filter (Blurred)', 'Optimized Result (Median + Closing)']
    images = [img, mean_blurred, final_result]

    plt.figure(figsize=(20, 10))
    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.imshow(images[i], cmap='gray')
        plt.title(titles[i], fontsize=14)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
img1 = cv2.imread("1.jpeg", 0)
img2 = cv2.imread("2.jpg", 0)
img3 = cv2.imread("3.jpg", 0)

images = [img1, img2, img3]
titles = ["img1", "img2", "Img3"]

plt.figure(figsize=(12, 10))

for i in range(3):
    
    img = images[i]
    
    sobel_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)
    sobel_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)
    
    sobel_mag = cv2.magnitude(sobel_x, sobel_y)
    sobel_mag = cv2.convertScaleAbs(sobel_mag)
    
    canny = cv2.Canny(img, 50, 150)
    
    plt.subplot(3, 3, i*3 + 1)
    plt.imshow(img, cmap='gray')
    plt.title(f"{titles[i]} - Original")
    plt.axis("off")
    
    plt.subplot(3, 3, i*3 + 2)
    plt.imshow(sobel_mag, cmap='gray')
    plt.title("Sobel")
    plt.axis("off")
    
    plt.subplot(3, 3, i*3 + 3)
    plt.imshow(canny, cmap='gray')
    plt.title("Canny")
    plt.axis("off")

plt.tight_layout()
plt.show()
